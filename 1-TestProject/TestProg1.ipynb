# %% [markdown]
# ## In the name of GOD
# # Class: Data mining
# ### Trem: 992
# ### Esmaeil Bagheri
# ### 1400/2/21

# %%
import numpy as np     # numerical python ex. array,...
import pandas as pd    # PreProcessing, Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# student=pd.read_excel("StudentSampleDataset-100.xls")    # read_csv: for .csv    read_excel: for .xls
patient=pd.read_excel("HeartFailure.xlsx")
# patient.head(10)
# patient.tail(10)
# patient.shape
# patient.info()
# patient[80:90]
# patient['Age']
# patient['Age'].unique()
# patient['Age'].value_counts()
# patient[patient['Age']==70]
# patient.describe()
patient.hist(bins=50,figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Gender'}>,
#         <AxesSubplot:title={'center':'BMI'}>,
#         <AxesSubplot:title={'center':'Cholesterol'}>],
#        [<AxesSubplot:title={'center':'Family history'}>,
#         <AxesSubplot:title={'center':'Dislip'}>,
#         <AxesSubplot:title={'center':'Smoking'}>,
#         <AxesSubplot:title={'center':'Sport'}>],
#        [<AxesSubplot:title={'center':'Salt'}>,
#         <AxesSubplot:title={'center':'Stress'}>,
#         <AxesSubplot:title={'center':'Dia bp'}>,
#         <AxesSubplot:title={'center':'Sys bp'}>],
#        [<AxesSubplot:title={'center':'Heart failure'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
sns.countplot(x=patient['BMI'],data=patient['BMI'])  
plt.show()

patient.groupby('BMI').size()
# Out:
# BMI
# 1     79
# 2    139
# 3    111
# 4    121
# dtype: int64
